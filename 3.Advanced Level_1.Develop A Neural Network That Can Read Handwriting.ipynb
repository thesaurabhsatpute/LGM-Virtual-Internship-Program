# %% [markdown]
# **Name: Saurabh Ashok Satpute**
#
# LGM VIP: Data Science Internship
#
# 3.Advanced Level Task -1.Develop A Neural Network That Can Read Handwriting
#
# Language-Python
#
# Software-Google Colab
#
#   Dataset-https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
#
#   **Importing Required Libraries**

# %%
import io 
import numpy as np 
import tensorflow as tf
from PIL import Image
import pandas as pd 
import seaborn as sb 
from google.colab import files 
import matplotlib.pyplot as plt 
from keras.datasets import mnist

# %%
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
plt.imshow(X_train[0],cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# **Normalizing X_train & X_test**

# %%
X_train=tf.keras.utils.normalize(X_train,axis=1)
X_test=tf.keras.utils.normalize(X_test,axis=1)
plt.imshow(X_train[0],cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# **Sequential Model**

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2614 - accuracy: 0.9243
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1047 - accuracy: 0.9681
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0710 - accuracy: 0.9779
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0521 - accuracy: 0.9828
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0403 - accuracy: 0.9866
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0309 - accuracy: 0.9900
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0239 - accuracy: 0.9921
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0208 - accuracy: 0.9928
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9947
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944

# %%
model_loss,model_accu=model.evaluate(X_test,Y_test)
print(model_loss,model_accu)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1216 - accuracy: 0.9718
# 0.12158690392971039 0.9718000292778015

# %% [markdown]
# **Prediction**

# %%
predicts=model.predict([X_test])
print(predicts)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'tuple'> input: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 28, 28) dtype=float32>,)
# Consider rewriting this model with the Functional API.
# [[1.12324680e-13 1.88176107e-11 3.64960617e-10 ... 1.00000000e+00
#   8.76094139e-15 4.19028978e-11]
#  [4.10439641e-17 3.52989887e-10 1.00000000e+00 ... 8.60904501e-14
#   2.75839981e-18 4.80456659e-26]
#  [1.54033708e-09 9.99104917e-01 4.85900046e-07 ... 8.49444012e-04
#   5.71225883e-06 1.81953350e-08]
#  ...
#  [1.07556942e-13 3.05372325e-11 9.65989069e-15 ... 1.26825439e-09
#   6.78678058e-10 1.48804617e-07]
#  [8.44749704e-12 3.37609609e-15 8.73760733e-15 ... 3.45774407e-13
#   3.50564378e-09 1.50831199e-15]
#  [5.46238685e-18 2.54784842e-15 3.38899947e-16 ... 9.97531856e-22
#   1.07060755e-14 6.76997204e-18]]

# %%
print(np.argmax(predicts[0]))
# Out:
# 7

# %%
plt.imshow(X_test[0])
plt.show()
